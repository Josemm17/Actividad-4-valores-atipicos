# %% [markdown]
# <a href="https://colab.research.google.com/github/Josemm17/Actividad-4-valores-atipicos/blob/main/Gastos%20Costos2022/Valores_atipicos2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('gastos_costos_2022_1')

# %%
#Verificamos información del DataFrame
#data.info()
data.head()
# Out:
#    Unnamed: 0       Fecha         Folio                                  UUID  \
# 0           0  2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1           1  2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2           2  2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3           3  2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4           4  2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
#
#              RFC                         Proveedor                TIPO GASTO  \
# 0   BLE1512082R9      BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 1   BLE1512082R9      BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 2   BNM840515VB1    BANCO NACIONAL DE MEXICO, S.A.         COMISION BANCARIA
# 3  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                   COMPRAS
# 4  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                   COMPRAS
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2577 non-null   int64
#  1   Fecha        2577 non-null   object
#  2   Folio        2577 non-null   object
#  3   UUID         2577 non-null   object
#  4   RFC          2577 non-null   object
#  5   Proveedor    2577 non-null   object
#  6   TIPO GASTO   2577 non-null   object
#  7   Descripción  2577 non-null   object
#  8   MP           2577 non-null   object
#  9   TC           2577 non-null   float64
#  10  Importe      2577 non-null   float64
#  11  IVA          2577 non-null   float64
#  12  RET ISR      2577 non-null   float64
#  13  RET IVA      2577 non-null   float64
#  14  Otros        0 non-null      float64
#  15  TOTAL MX     2577 non-null   float64
#  16  TOTAL SAT    2577 non-null   float64
#  17  Tipo         2577 non-null   object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0        0
# Fecha             0
# Folio             0
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP                0
# TC                0
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza          801
# dtype: int64

# %%
data1 =data.fillna(method="ffill")
data1
# Out:
# <ipython-input-6-0ebf61982236>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 =data.fillna(method="ffill")
#       Unnamed: 0       Fecha         Folio  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# ...

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Eliminamos columnas innecesarias
data2= data1.drop(['Unnamed: 0', "Fecha", "Folio", "UUID", "RFC", "Proveedor", "TIPO GASTO", "Descripción", "MP", "Tipo", "Status","Poliza" ], axis=1)
data2
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60    6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30    6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# ...   ...       ...     ...      ...      ...    ...       ...        ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62   17826.62
# 2574  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2575  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2576  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
#
# [2577 rows x 8 columns]

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido TC               5.984644
# Importe      34975.501132
# IVA           5048.646001
# RET ISR        977.619941
# RET IVA       1046.847384
# Otros                 NaN
# TOTAL MX     39054.094273
# TOTAL SAT    39095.543969
# dtype: float64
# Limite inferior permitido TC              -3.617294
# Importe     -26990.441616
# IVA          -4069.819702
# RET ISR       -902.558225
# RET IVA       -964.592475
# Otros                 NaN
# TOTAL MX    -30247.525081
# TOTAL SAT   -30172.959879
# dtype: float64

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#       TC  Importe  IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT
# 0    NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 1    NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 2    NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 3    NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 4    NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# ...   ..      ...  ...      ...      ...    ...       ...        ...
# 2572 NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 2573 NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 2574 NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 2575 NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
# 2576 NaN      NaN  NaN      NaN      NaN    NaN       NaN        NaN
#
# [2577 rows x 8 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60    6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30    6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# ...   ...       ...     ...      ...      ...    ...       ...        ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62   17826.62
# 2574  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2575  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2576  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
#
# [2577 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# TC             18
# Importe        36
# IVA            31
# RET ISR        32
# RET IVA        32
# Otros        2577
# TOTAL MX       36
# TOTAL SAT      36
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60    6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30    6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# ...   ...       ...     ...      ...      ...    ...       ...        ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62   17826.62
# 2574  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2575  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
# 2576  1.2      0.00    0.00      0.0      0.0    NaN      0.00       0.00
#
# [2577 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# TC              0
# Importe         0
# IVA             0
# RET ISR         0
# RET IVA         0
# Otros        2577
# TOTAL MX        0
# TOTAL SAT       0
# dtype: int64

# %%
# Unimos la columnas con el dataframe

columnas_obj=data1[['Unnamed: 0', "Fecha", "Folio", "UUID", "RFC", "Proveedor", "TIPO GASTO", "Descripción", "MP", "Tipo", "Status","Poliza"]]
Datos_limpios2022 = pd.concat([columnas_obj, data_clean], axis=1)
Datos_limpios2022
# Out:
#       Unnamed: 0       Fecha         Folio  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# 3     B5E4B4EB-6C2F-11EC-BB9D-00155D014009  ZEGC530520V4A
# 4     BB6756D1-6CCD-11EC-947D-00155D014407  ZEGC530520V4A
# ...                                    ...            ...
# ...

# %%
Datos_limpios2022.to_csv("Datos_limpios2022")
from google.colab import files


files.download("Datos_limpios2022")
